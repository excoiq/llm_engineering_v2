# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, update_display

# %%
# constants
openai = OpenAI()
load_dotenv(override=True)

api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')


if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("OpenAI API Key -> OK")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")

if anthropic_api_key:
    print("Anthoropic API KEY -> OK")
else:
    print("Anthoripic API Key -> Missing")

if google_api_key:
    print("Google API KEY -> OK")
else:
    print("Google API Key -> Missing")
# Out:
# OpenAI API Key -> OK
# Anthoropic API KEY -> OK
# Google API KEY -> OK

# %%
# OpenAI LLM
MODEL_GPT = 'gpt-4o-mini'

def answer_GPT(question):
    response = openai.chat.completions.create(
        model=MODEL_GPT,
        messages=[
            {"role" : "user", "content" : question}
        ]
    )
    answer = response.choices[0].message.content
    display(Markdown(answer))
    #return answer

def stream_answer_GPT(question):
    stream = openai.chat.completions.create(
        model=MODEL_GPT,
        messages=[
            {"role" : "user", "content" : question}
        ],
        stream=True
    )
    answer = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        answer += chunk.choices[0].delta.content or ''
        update_display(Markdown(answer), display_id=display_handle.display_id)

# %%
OLLAMA_BASE_URL = "http://localhost:11434/v1"
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')
MODEL_LLAMA = 'llama3.2'

def answer_llama(question):
    response = ollama.chat.completions.create(
        model=MODEL_LLAMA,
        messages=[
            {"role" : "user", "content" : question}
        ]
    )
    answer = response.choices[0].message.content
    display(Markdown(answer))
    #return answer

def stream_answer_llama(question):
    stream = ollama.chat.completions.create(
        model=MODEL_LLAMA,
        messages=[
            {"role" : "user", "content" : question}
        ],
        stream=True
    )
    answer = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        answer += chunk.choices[0].delta.content or ''
        update_display(Markdown(answer), display_id=display_handle.display_id)

# %%
anthropic_url = "https://api.anthropic.com/v1/"
anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
MODEL_ANTHROPIC = 'claude-sonnet-4-5-20250929'


def answer_anthropic(question):
    response = anthropic.chat.completions.create(
        model=MODEL_ANTHROPIC,
        messages=[
            {"role" : "user", "content" : question}
        ]
    )
    answer = response.choices[0].message.content
    display(Markdown(answer))
    #return answer

# %%
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
MODEL_GEMINI = 'gemini-2.5-flash-lite-preview-09-2025'


def answer_gemini(question):
    response = gemini.chat.completions.create(
        model=MODEL_GEMINI,
        messages=[
            {"role" : "user", "content" : question}
        ]
    )
    answer = response.choices[0].message.content
    display(Markdown(answer))
    #return answer

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# Get gpt-4o-mini to answer, with streaming

#answer_GPT(question)
stream_answer_GPT(question)
# Out:
# The code you've provided is a Python expression that utilizes a combination of set comprehension and the `yield from` statement. Here’s a breakdown of what it does:
#
# 1. **Set Comprehension**:
#    - `{book.get("author") for book in books if book.get("author")}` is a set comprehension that iterates over a collection named `books`.
#    - Each `book` is expected to be a dictionary (or an object that functions similarly), and it attempts to retrieve the value associated with the key `"author"` using `book.get("author")`.
#    - The condition `if book.get("author")` ensures that only books that have a non-None and non-empty author value are included in the set.
#    - The `{}` indicates that this is a set comprehension, which means the authors will be collected into a set, automatically eliminating any duplicates.
#
# 2. **Yield from**:
# ...

# %%
#answer_llama(question)

#answer_llama(question)
stream_answer_llama(question)
# Out:
# This line of Python code is using a feature called generator expressions, which are used to generate an iterable sequence. Let's break it down:
#
# - `yield from`: This keyword is used with generators or coroutines to delegate the execution of code in another iterable.
#
# - `{book.get("author") for book in books if book.get("author")}`: This part is a generator expression that iterates over a list or other iterable called `books`. For each item `book` in `books`, it calls `book.get("author")` to retrieve the author of the book. The `if book.get("author")` condition ensures that only books with authors are processed.
#
# The entire `yield from` construct creates an iterator over the book authors without fetching the entire list of books at once, but instead generates them on demand.
#
# Here is a more verbose and readable way to achieve this:
#
# ```python
# def get_book_authors(books):
#     for book in books:
#         if book.get("author"):
#             yield book["author"]
#
# ...

# %%
answer_anthropic(question)
# Out:
# # Code Explanation
#
# This code **yields unique author names** from a collection of books, filtering out any books without an author.
#
# ## Breaking it down:
#
# ```python
# yield from {book.get("author") for book in books if book.get("author")}
# ```
#
# 1. **`for book in books`** - Iterates through a collection of book dictionaries
#
# 2. **`book.get("author")`** - Safely retrieves the "author" key from each book dictionary (returns `None` if key doesn't exist, avoiding KeyError)
#
# 3. **`if book.get("author")`** - Filters out books where author is missing/None/empty
#
# 4. **`{ ... }`** - **Set comprehension** that creates a set of authors, automatically **removing duplicates**
#
# 5. **`yield from`** - Yields each element from the set individually (unpacks the set)
#
# ## Why use this approach?
#
# - **`get()` method**: Safe dictionary access - won't crash if "author" key is missing
# - **Set `{}`**: Automatically deduplicates authors (if multiple books have the same author)
# ...

# %%
answer_gemini(question)
# Out:
# This code snippet is a Python **generator expression** combined with the `yield from` statement. It's a very concise and efficient way to process a collection of data (likely a list of dictionaries representing books) and yield its results one by one.
#
# Here is a detailed breakdown of what each part does and why it's used:
#
# ---
#
# ## 1. The Generator Expression: `{book.get("author") for book in books if book.get("author")}`
#
# This part is a **set comprehension** (though often used in generator expressions, the surrounding context of `yield from` suggests the intention is to iterate over the results, so it behaves like a generator expression in this context, producing a stream of values).
#
# Let's break down the inner logic:
#
# *   **`for book in books`**: It iterates over an existing iterable named `books`. We can infer that `books` is likely a list or sequence where each element (`book`) is a dictionary.
# ...
